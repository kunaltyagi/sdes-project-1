# %%
# %matplotlib inline
# %run oscillator.py
# %run plot.py
from matplotlib import animation, rc
from IPython.display import HTML

# %%
a = Oscillator(mu=2, x0=2)
ans = a.solve(0, 24, 0.01)
x1 = Sequence(ans[:,0], '$x$')
x2 = Sequence(ans[:,1], '$\dot{x}$')

# %%
fig=plt.figure()
ax=fig.add_subplot(111,autoscale_on=False, xlim=(0,6), ylim=(-4,4))
ax.grid()
line1, line2, = ax.plot([],[],'b-',[],[],'r-', lw=2)
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)

# %%
def init():
    line1.set_data([], [])
    line2.set_data([], [])
    time_text.set_text('')
    return line1, line2, time_text

# %%
def animate_line(i):
    y = np.arange(0,6, 0.01)
    line1.set_data(y, x1.data[i:600+i])
    line2.set_data(y, x2.data[i:600+i])
    time_text.set_text(time_template % (i*0.01))
    return line1, line2, time_text

# %%
x1.plot()
plt.show()

# %%
anim = animation.FuncAnimation(fig, animate_line, init_func=init,
                               frames=760*2, interval=20, blit=True)

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
print(animation.writers.list())
# Out:
# ['ffmpeg_file', 'ffmpeg', 'imagemagick_file', 'imagemagick']

# %%
fig=plt.figure()
ax=fig.add_subplot(111,autoscale_on=False, xlim=(-3,3), ylim=(-4,4))
ax.grid()
line1, line2, = ax.plot([], [], 'o',[],[],'r-',lw=2)
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)

# %%
def animate_point(i):
    i = i*2
    line1.set_data(x1.data[i], x2.data[i])
    line2.set_data(x1.data[0:i], x2.data[0:i])
    time_text.set_text(time_template % (i*0.01))
    return line1, line2, time_text

# %%
anim = animation.FuncAnimation(fig, animate_point, init_func=init,
                               frames=760, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-1e2c505c9268> in <module>()
#       1 anim = animation.FuncAnimation(fig, animate_point, init_func=init,
#       2                                frames=760, interval=20, blit=True)
# ----> 3 HTML(anim.to_html5_video())
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/animation.py in to_html5_video(self)
#     981                                 bitrate=rcParams['animation.bitrate'],
#     982                                 fps=1000. / self._interval)
# --> 983                 self.save(f.name, writer=writer)
#     984
#     985             # Now open and base64 encode
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#     830                 for anim in all_anim:
# ...

# %%
a = Oscillator(mu=2, x0=2)
ans = a.solve(0, 24, 0.01, True)
x1 = Sequence(ans[:,0], '$x$')
x2 = Sequence(ans[:,1], '$\dot{x}$')

# %%
fig=plt.figure()
ax=fig.add_subplot(111,autoscale_on=False, xlim=(-3,3), ylim=(-4,4))
ax.grid()
line1, line2, = ax.plot([], [], 'o',[],[],'r-',lw=2)
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)
anim = animation.FuncAnimation(fig, animate_point, init_func=init,
                               frames=760, interval=20, blit=True)
print("This is not a good animation")
#HTML(anim.to_html5_video())
# Out:
# This is not a good animation

# %%
a = Oscillator(mu=5, x0=2)
ans = a.solve(0, 24, 0.01)
x1 = Sequence(ans[:,0], '$x$')
x2 = Sequence(ans[:,1], '$\dot{x}$')
fig=plt.figure();
ax=fig.add_subplot(111,autoscale_on=False, xlim=(-3,3), ylim=(-8,8));
ax.grid()
line1, line2, = ax.plot([], [], 'o',[],[],'r-',lw=2);
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)
anim = animation.FuncAnimation(fig, animate_point, init_func=init,
                               frames=570, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
a = Oscillator(mu=1, x0=2)
ans = a.solve(0, 24, 0.01)
x1 = Sequence(ans[:,0], '$x$')
x2 = Sequence(ans[:,1], '$\dot{x}$')
fig=plt.figure();
ax=fig.add_subplot(111,autoscale_on=False, xlim=(-3,3), ylim=(-8,8));
ax.grid()
line1, line2, = ax.plot([], [], 'o',[],[],'r-',lw=2);
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)
anim = animation.FuncAnimation(fig, animate_point, init_func=init,
                               frames=325, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
a = Oscillator(mu=0.5, x0=1)
ans = a.solve(0, 24, 0.01)
x1 = Sequence(ans[:,0], '$x$')
x2 = Sequence(ans[:,1], '$\dot{x}$')
fig=plt.figure();
ax=fig.add_subplot(111,autoscale_on=False, xlim=(-3,3), ylim=(-8,8));
ax.grid()
line1, line2, = ax.plot([], [], 'o',[],[],'r-',lw=2);
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)
anim = animation.FuncAnimation(fig, animate_point, init_func=init,
                               frames=770, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# <video width="432.0" height="288.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
x2.set_color('r')
x1.plot()
x2.plot()
plt.legend()
plt.show()

# %%
a = Oscillator(mu=0, x0=1)
ans = a.solve(0, 24, 0.01)
x1 = Sequence(ans[:,0], '$x$')
x2 = Sequence(ans[:,1], '$\dot{x}$')
fig=plt.figure();
ax=fig.add_subplot(111,autoscale_on=False, xlim=(-3,3), ylim=(-8,8));
ax.grid()
line1, line2, = ax.plot([], [], 'o',[],[],'r-',lw=2);
time_template = 'time = %.1fs'
time_text = ax.text(0.05, 0.9, '', transform=ax.transAxes)
anim = animation.FuncAnimation(fig, animate_point, init_func=init,
                               frames=300, interval=20, blit=True)
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1108075932cf> in <module>()
# ----> 1 a = Oscillator(mu=0, x0=1)
#       2 ans = a.solve(0, 24, 0.01)
#       3 x1 = Sequence(ans[:,0], '$x$')
#       4 x2 = Sequence(ans[:,1], '$\dot{x}$')
#       5 fig=plt.figure();
#
# NameError: name 'Oscillator' is not defined

# %%
x2.set_color('r')
x1.plot()
x2.plot()
plt.legend()
plt.show()

# %%
line1.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-37e0c6f49cfb> in <module>()
# ----> 1 line1.plot()
#       2 plt.show()
#
# AttributeError: 'Line2D' object has no attribute 'plot'
